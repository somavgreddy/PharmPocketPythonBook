# %%
###########################################################
# Comparison operators — return True or False
###########################################################

print(500 > 250)     # True  — is 500 greater than 250?
print(100 == 100)    # True  — is 100 equal to 100?
print(500 != 250)    # True  — is 500 not equal to 250?
print(30 <= 30)      # True  — is 30 less than or equal to 30?

print("***********************************************")
# Logical operators: and, or, not
age = 65
weight=91.2
has_kidney_issue = False
sex="M"
Name="Shiv Nayar"

# Check if dose adjustment is needed:
if age > 60 or has_kidney_issue:
    print('Reduce dose by 50%')

# Check if patient is eligible for a drug:
blood_pressure = 140
is_eligible = blood_pressure < 160 or age < 70
print(f'Eligible: {is_eligible}')   # True
print(f'Is the patient Male? {sex=="M"}') # True
print(f'Is the patient Over weight? {weight>=100}') # False
print(f'Is the patient not having kidney issue? {not has_kidney_issue}') # True
print(Name.upper())
# Out:
# True
# True
# True
# True
# ***********************************************
# Reduce dose by 50%
# Eligible: True
# Is the patient Male? True
# Is the patient Over weight? False
# Is the patient not having kidney issue? True
# SHIV NAYAR
