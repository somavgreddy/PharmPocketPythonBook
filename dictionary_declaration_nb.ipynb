# %%
drug = {
    "name": "Metformin",
    "dosage_mg": 500,
    "form": "tablet",
    "manufacturer": "Generic Pharma Inc.",
    "requires_prescription": True,
    "remedy_for": "Diabetes"

}

print(drug["name"])          # Metformin
print(drug["dosage_mg"])     # 500
print(drug["remedy_for"])    # Diabetes
# Out:
# Metformin
# 500
# Diabetes
