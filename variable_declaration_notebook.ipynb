# %%
# Pharmaceutical Variables Example – let’s Call this notebook
# variable_declaration_notebook.ipynb


drug_name = 'Metformin'        # Text (string)
patient_age = 45               # Whole number (integer)
body_weight_kg = 68.5          # Decimal number (float)
is_diabetic = True             # Yes/No value (boolean)
active_ingredients = ['Metformin', 'Glipizide']  # List

print(drug_name)               # Output: Metformin
print(patient_age)             # Output: 45
print(body_weight_kg)          # Output: 68.5
print(is_diabetic)             # Output: True
print(type(drug_name))         # Output: <class 'str'>
print(type(patient_age))       # Output: <class 'int'>
print(type(body_weight_kg))    # Output: <class 'float'>
print(type(is_diabetic))       # Output: <class 'bool'>
# Out:
# Metformin
# 45
# 68.5
# True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
